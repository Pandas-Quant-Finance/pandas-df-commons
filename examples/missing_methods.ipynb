# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from pandas_df_commons.patched import pd
# Out:
# pandas version 1.5.1

# %%
df = pd.DataFrame({"A": np.random.random(100)})

# %%
df.X.cumpct_change().plot()
# Out:
# <AxesSubplot: >

# %%
df.X.cumapply(lambda last, x: (last + x) / 2, 0).plot()
# Out:
# <AxesSubplot: >

# %%
# rolling apply return multiple dimensions
df.X.rolling_apply(3, lambda x: pd.concat([x * 2, x * 3])).tail(9)
# Out:
#               A
# 98 96  0.512793
#    97  1.524581
#    98  1.795916
# 99 97  1.016388
#    98  1.197277
#    99  1.538246
#    97  1.524581
#    98  1.795916
#    99  2.307369
